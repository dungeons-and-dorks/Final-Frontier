# %% [markdown]
# # Final Frontier
#
# Project workbook for space project

# %%
#Imports

import warnings
warnings.filterwarnings("ignore")

#for data manipulation
import pandas as pd

#data visualization
import seaborn as sns
import matplotlib.pyplot as plt

#Set figure size for all plots
plt.rc("figure", figsize = (16,16))

#Set fontsize for titles
plt.rc("font", size=14)

# %%
#bring in dataframe

df = pd.read_csv("../Data/Space_Corrected.csv")

# %%
df.shape
# Out:
# (4324, 9)

# %%
df.sample(4)
# Out:
#       Unnamed: 0  Unnamed: 0.1      Company Name  \
# 1957        1957          1957         RVSN USSR
# 2657        2657          2657  General Dynamics
# 121          121           121              ISRO
# 812          812           812               ULA
#
#                                                Location  \
# 1957        Site 90/19, Baikonur Cosmodrome, Kazakhstan
# 2657          SLC-36A, Cape Canaveral AFS, Florida, USA
# 121   Second Launch Pad, Satish Dhawan Space Centre,...
# 812             SLC-2W, Vandenberg AFB, California, USA
#
#                            Datum                                     Detail  \
# 1957  Mon Mar 14, 1988 14:21 UTC                    Tsyklon-2 | Cosmos 1932
# 2657  Fri Sep 30, 1977 01:02 UTC  Atlas-SLV3D Centaur-D1AR | Intelsat 4A F5
# 121   Mon Jul 22, 2019 09:13 UTC  GSLV Mk III | Chandrayaan-2 lunar mission
# 812   Fri Jun 20, 2008 07:46 UTC                Delta II 7320-10C | Jason-2
#
#       Status Rocket  Rocket Status Mission
# 1957  StatusRetired     NaN        Success
# 2657  StatusRetired     NaN        Failure
# 121    StatusActive   62.0         Success
# 812   StatusRetired     NaN        Success

# %%
#drop columns
df.drop(columns=["Unnamed: 0", "Unnamed: 0.1"], inplace = True)

# %%
df
# Out:
#      Company Name                                           Location  \
# 0          SpaceX         LC-39A, Kennedy Space Center, Florida, USA
# 1            CASC  Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 2          SpaceX                      Pad A, Boca Chica, Texas, USA
# 3       Roscosmos       Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 4             ULA           SLC-41, Cape Canaveral AFS, Florida, USA
# ...           ...                                                ...
# 4319      US Navy           LC-18A, Cape Canaveral AFS, Florida, USA
# 4320         AMBA           LC-26A, Cape Canaveral AFS, Florida, USA
# 4321      US Navy           LC-18A, Cape Canaveral AFS, Florida, USA
# 4322    RVSN USSR          Site 1/5, Baikonur Cosmodrome, Kazakhstan
# 4323    RVSN USSR          Site 1/5, Baikonur Cosmodrome, Kazakhstan
#
#                            Datum  \
# 0     Fri Aug 07, 2020 05:12 UTC
# 1     Thu Aug 06, 2020 04:01 UTC
# 2     Tue Aug 04, 2020 23:57 UTC
# 3     Thu Jul 30, 2020 21:25 UTC
# 4     Thu Jul 30, 2020 11:50 UTC
# ...                          ...
# 4319  Wed Feb 05, 1958 07:33 UTC
# 4320  Sat Feb 01, 1958 03:48 UTC
# 4321  Fri Dec 06, 1957 16:44 UTC
# 4322  Sun Nov 03, 1957 02:30 UTC
# 4323  Fri Oct 04, 1957 19:28 UTC
#
#                                             Detail  Status Rocket  Rocket  \
# 0     Falcon 9 Block 5 | Starlink V1 L9 & BlackSky   StatusActive   50.0
# 1              Long March 2D | Gaofen-9 04 & Q-SAT   StatusActive  29.75
# 2               Starship Prototype | 150 Meter Hop   StatusActive     NaN
# 3     Proton-M/Briz-M | Ekspress-80 & Ekspress-103   StatusActive   65.0
# 4                       Atlas V 541 | Perseverance   StatusActive  145.0
# ...                                            ...            ...     ...
# 4319                     Vanguard | Vanguard TV3BU  StatusRetired     NaN
# 4320                           Juno I | Explorer 1  StatusRetired     NaN
# 4321                       Vanguard | Vanguard TV3  StatusRetired     NaN
# 4322                    Sputnik 8K71PS | Sputnik-2  StatusRetired     NaN
# 4323                    Sputnik 8K71PS | Sputnik-1  StatusRetired     NaN
#
#      Status Mission
# 0           Success
# 1           Success
# 2           Success
# 3           Success
# 4           Success
# ...             ...
# 4319        Failure
# 4320        Success
# 4321        Failure
# 4322        Success
# 4323        Success
#
# [4324 rows x 7 columns]

# %%
#check 
df.isnull().sum()
# Out:
# Company Name         0
# Location             0
# Datum                0
# Detail               0
# Status Rocket        0
#  Rocket           3360
# Status Mission       0
# dtype: int64

# %%
#check how many unique companies companies are listed
df["Company Name"].nunique()
# Out:
# 56

# %%
df["Company Name"].unique()
# Out:
# array(['SpaceX', 'CASC', 'Roscosmos', 'ULA', 'JAXA', 'Northrop', 'ExPace',
#        'IAI', 'Rocket Lab', 'Virgin Orbit', 'VKS RF', 'MHI', 'IRGC',
#        'Arianespace', 'ISA', 'Blue Origin', 'ISRO', 'Exos', 'ILS',
#        'i-Space', 'OneSpace', 'Landspace', 'Eurockot', 'Land Launch',
#        'CASIC', 'KCST', 'Sandia', 'Kosmotras', 'Khrunichev', 'Sea Launch',
#        'KARI', 'ESA', 'NASA', 'Boeing', 'ISAS', 'SRC', 'MITT', 'Lockheed',
#        'AEB', 'Starsem', 'RVSN USSR', 'EER', 'General Dynamics',
#        'Martin Marietta', 'Yuzhmash', 'Douglas', 'ASI', 'US Air Force',
#        'CNES', 'CECLES', 'RAE', 'UT', 'OKB-586', 'AMBA',
#        "Arm??e de l'Air", 'US Navy'], dtype=object)

# %%
df["Status Mission"].nunique()
# Out:
# 4

# %%
df["Status Mission"].unique()
# Out:
# array(['Success', 'Failure', 'Prelaunch Failure', 'Partial Failure'],
#       dtype=object)

# %%
#create a crosstab for comanies and status mission
ctab_df = pd.crosstab(df["Status Mission"], df["Company Name"])

# %%
#function to create a distro plot

def distro_plot_for_single_column(dataframe, column_name):
    """Taked in a dataframe name and column name
    and return a distrobution plot for that column"""
    
    #Set figure size for all plots
    plt.rc("figure", figsize = (16,16))

    #Set fontsize for titles
    plt.rc("font", size=14)
    
    #Set color for distro plot
    c = "#5B0A91"
    plt.title(f"Distribution plot for {column_name}")
    sns.distplot(dataframe[column_name], color = c)

# %%
def ditro_plot_for_entire_df(df):
    """
    Takes in a numerical only dataframe such as a crosstab
    and returns Distribution plots for each column in the
    dataframe.
    """
    for i, col in enumerate(df.columns):
        plt.figure(i)
        distro_plot_for_single_column(df, col)

# %%
#test function to make sure it works and comment out after testing
#ditro_plot_for_entire_df(ctab_df)

# %%
df
# Out:
#      Company Name                                           Location  \
# 0          SpaceX         LC-39A, Kennedy Space Center, Florida, USA
# 1            CASC  Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 2          SpaceX                      Pad A, Boca Chica, Texas, USA
# 3       Roscosmos       Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 4             ULA           SLC-41, Cape Canaveral AFS, Florida, USA
# ...           ...                                                ...
# 4319      US Navy           LC-18A, Cape Canaveral AFS, Florida, USA
# 4320         AMBA           LC-26A, Cape Canaveral AFS, Florida, USA
# 4321      US Navy           LC-18A, Cape Canaveral AFS, Florida, USA
# 4322    RVSN USSR          Site 1/5, Baikonur Cosmodrome, Kazakhstan
# 4323    RVSN USSR          Site 1/5, Baikonur Cosmodrome, Kazakhstan
#
#                            Datum  \
# 0     Fri Aug 07, 2020 05:12 UTC
# 1     Thu Aug 06, 2020 04:01 UTC
# 2     Tue Aug 04, 2020 23:57 UTC
# 3     Thu Jul 30, 2020 21:25 UTC
# 4     Thu Jul 30, 2020 11:50 UTC
# ...                          ...
# 4319  Wed Feb 05, 1958 07:33 UTC
# 4320  Sat Feb 01, 1958 03:48 UTC
# 4321  Fri Dec 06, 1957 16:44 UTC
# 4322  Sun Nov 03, 1957 02:30 UTC
# 4323  Fri Oct 04, 1957 19:28 UTC
#
#                                             Detail  Status Rocket  Rocket  \
# 0     Falcon 9 Block 5 | Starlink V1 L9 & BlackSky   StatusActive   50.0
# 1              Long March 2D | Gaofen-9 04 & Q-SAT   StatusActive  29.75
# 2               Starship Prototype | 150 Meter Hop   StatusActive     NaN
# 3     Proton-M/Briz-M | Ekspress-80 & Ekspress-103   StatusActive   65.0
# 4                       Atlas V 541 | Perseverance   StatusActive  145.0
# ...                                            ...            ...     ...
# 4319                     Vanguard | Vanguard TV3BU  StatusRetired     NaN
# 4320                           Juno I | Explorer 1  StatusRetired     NaN
# 4321                       Vanguard | Vanguard TV3  StatusRetired     NaN
# 4322                    Sputnik 8K71PS | Sputnik-2  StatusRetired     NaN
# 4323                    Sputnik 8K71PS | Sputnik-1  StatusRetired     NaN
#
#      Status Mission
# 0           Success
# 1           Success
# 2           Success
# 3           Success
# 4           Success
# ...             ...
# 4319        Failure
# 4320        Success
# 4321        Failure
# 4322        Success
# 4323        Success
#
# [4324 rows x 7 columns]

# %% [markdown]
# To do:
#
# Use a label encoder on status mission

# %% [markdown]
# ## Mission Status Distribution

# %%
df_1 = df["Status Mission"].value_counts().reset_index()

# %%
df_1
# Out:
#                index  Status Mission
# 0            Success            3879
# 1            Failure             339
# 2    Partial Failure             102
# 3  Prelaunch Failure               4

# %%
plt.figure("figure", figsize = (16,16))
sns.barplot(df_1["index"], df_1["Status Mission"], color="#39FF14")

# %%
def get_space_data():
    # Pull in the data into a pandas data frame
    df = pd.read_csv("../data/Space_Corrected.csv")

    # drop excess columns generated by pandas
    df.drop(columns=["Unnamed: 0", "Unnamed: 0.1"], inplace=True)

    # Rename the columns
    df.pipe(rename_columns)

    # Fix the values within the rocket_status column
    df.pipe(fix_rocket_status)
    
    # Fix the values/type within mission_cost
    df.pipe(fix_mission_cost)

    # Change the date column to a pandas datetime type
    df.date_time = pd.to_datetime(df.date_time)
    
    # Create the year column
    df['year'] = df.date_time.apply(lambda datetime: datetime.year)
    
    # Create the Month column
    df['month'] = df.date_time.apply(lambda datetime: datetime.month)

    # Set the index to be the datetime column, then drop it from the dataframe
    df.set_index(df.date_time, inplace=True)
    df.drop(columns="date_time", inplace=True)

    # Fill missing values with 0
    df.mission_cost.fillna(0, inplace=True)
    
    df.pipe(get_country_name)
    return df


def rename_columns(df):
    new_col_names = [
        "company_name",
        "location",
        "date_time",
        "rocket_type",
        "rocket_status",
        "mission_cost",
        "mission_status",
    ]
    df.columns = new_col_names
    return df


def fix_mission_cost(df):
    df.mission_cost = df.mission_cost.str.replace(' ', '')
    df.mission_cost = df.mission_cost.str.replace(',', '')
    df.mission_cost.astype(float)
    return df


def fix_rocket_status(df):
    df.loc[df.rocket_status == "StatusRetired", "rocket_status"] = "retired"
    df.loc[df.rocket_status == "StatusActive", "rocket_status"] = "active"
    return df

def get_country_name(df):
    """
    Takes in the a dataframe and return the Country name in 
    a new column
    """
    df['country'] = df['location'].str.split(', ').str[-1]
    df['country'].loc[df['country'] == 'Shahrud Missile Test Site'] = "Iran"
    df['country'].loc[df['country'] == 'New Mexico'] = 'United States of America'
    df['country'].loc[df['country'] == 'Yellow Sea'] = "China"
    df['country'].loc[df['country'] == 'Pacific Missile Range Facility'] = "United States of America"
    df['country'].loc[df['country'] == 'Pacific Ocean'] = "United States of America"
    df['country'].loc[df['country'] == 'Barents Sea'] = 'Russia'
    df['country'].loc[df['country'] == 'Gran Canaria'] = 'United States of America'
    df['country'].loc[df['country'] == 'USA'] = 'United States of America'
    return df

# %%
def mission_result(df):
    # Creating a new column and setting it's default as 1
    df['mission_result'] = 1
    
    # Slicing by the rows that contain a failure, then setting the result to 0
    df.loc[df.mission_status.str.contains('Failure'), 'mission_result'] = 0
    
    return df

# %%
df = get_space_data()

# %%
df = mission_result(df)

# %%
df.sample()
# Out:
#                           company_name  \
# date_time
# 1969-03-05 17:25:00+00:00    RVSN USSR
#
#                                                           location  \
# date_time
# 1969-03-05 17:25:00+00:00  Site 132/2, Plesetsk Cosmodrome, Russia
#
#                                                rocket_type rocket_status  \
# date_time
# 1969-03-05 17:25:00+00:00  Cosmos-3M (11K65M) | Cosmos 269       retired
#
#                           mission_cost mission_status  year  month country  \
# date_time
# 1969-03-05 17:25:00+00:00            0        Success  1969      3  Russia
#
#                            mission_result
# date_time
# 1969-03-05 17:25:00+00:00               1

# %%
df.head()
# Out:
#                           company_name  \
# date_time
# 2020-08-07 05:12:00+00:00       SpaceX
# 2020-08-06 04:01:00+00:00         CASC
# 2020-08-04 23:57:00+00:00       SpaceX
# 2020-07-30 21:25:00+00:00    Roscosmos
# 2020-07-30 11:50:00+00:00          ULA
#
#                                                                     location  \
# date_time
# 2020-08-07 05:12:00+00:00         LC-39A, Kennedy Space Center, Florida, USA
# 2020-08-06 04:01:00+00:00  Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 2020-08-04 23:57:00+00:00                      Pad A, Boca Chica, Texas, USA
# 2020-07-30 21:25:00+00:00       Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 2020-07-30 11:50:00+00:00           SLC-41, Cape Canaveral AFS, Florida, USA
#
#                                                             rocket_type  \
# date_time
# 2020-08-07 05:12:00+00:00  Falcon 9 Block 5 | Starlink V1 L9 & BlackSky
# 2020-08-06 04:01:00+00:00           Long March 2D | Gaofen-9 04 & Q-SAT
# 2020-08-04 23:57:00+00:00            Starship Prototype | 150 Meter Hop
# 2020-07-30 21:25:00+00:00  Proton-M/Briz-M | Ekspress-80 & Ekspress-103
# 2020-07-30 11:50:00+00:00                    Atlas V 541 | Perseverance
#
#                           rocket_status mission_cost mission_status  year  \
# date_time
# 2020-08-07 05:12:00+00:00        active         50.0        Success  2020
# 2020-08-06 04:01:00+00:00        active        29.75        Success  2020
# 2020-08-04 23:57:00+00:00        active            0        Success  2020
# 2020-07-30 21:25:00+00:00        active         65.0        Success  2020
# 2020-07-30 11:50:00+00:00        active        145.0        Success  2020
#
#                            month                   country  mission_result
# date_time
# 2020-08-07 05:12:00+00:00      8  United States of America               1
# 2020-08-06 04:01:00+00:00      8                     China               1
# 2020-08-04 23:57:00+00:00      8  United States of America               1
# 2020-07-30 21:25:00+00:00      7                Kazakhstan               1
# 2020-07-30 11:50:00+00:00      7  United States of America               1

# %%
df.country.value_counts()
# Out:
# Russia                      1398
# United States of America    1387
# Kazakhstan                   701
# France                       303
# China                        269
# Japan                        126
# India                         76
# Iran                          14
# New Zealand                   13
# Israel                        11
# Kenya                          9
# Australia                      6
# North Korea                    5
# South Korea                    3
# Brazil                         3
# Name: country, dtype: int64

# %%
#df['year'] = df.date_time.apply(lambda datetime: datetime.year)

# %%
df.head()
# Out:
#                           company_name  \
# date_time
# 2020-08-07 05:12:00+00:00       SpaceX
# 2020-08-06 04:01:00+00:00         CASC
# 2020-08-04 23:57:00+00:00       SpaceX
# 2020-07-30 21:25:00+00:00    Roscosmos
# 2020-07-30 11:50:00+00:00          ULA
#
#                                                                     location  \
# date_time
# 2020-08-07 05:12:00+00:00         LC-39A, Kennedy Space Center, Florida, USA
# 2020-08-06 04:01:00+00:00  Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 2020-08-04 23:57:00+00:00                      Pad A, Boca Chica, Texas, USA
# 2020-07-30 21:25:00+00:00       Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 2020-07-30 11:50:00+00:00           SLC-41, Cape Canaveral AFS, Florida, USA
#
#                                                             rocket_type  \
# date_time
# 2020-08-07 05:12:00+00:00  Falcon 9 Block 5 | Starlink V1 L9 & BlackSky
# 2020-08-06 04:01:00+00:00           Long March 2D | Gaofen-9 04 & Q-SAT
# 2020-08-04 23:57:00+00:00            Starship Prototype | 150 Meter Hop
# 2020-07-30 21:25:00+00:00  Proton-M/Briz-M | Ekspress-80 & Ekspress-103
# 2020-07-30 11:50:00+00:00                    Atlas V 541 | Perseverance
#
#                           rocket_status mission_cost mission_status  year  \
# date_time
# 2020-08-07 05:12:00+00:00        active         50.0        Success  2020
# 2020-08-06 04:01:00+00:00        active        29.75        Success  2020
# 2020-08-04 23:57:00+00:00        active            0        Success  2020
# 2020-07-30 21:25:00+00:00        active         65.0        Success  2020
# 2020-07-30 11:50:00+00:00        active        145.0        Success  2020
#
#                            month                   country  mission_result
# date_time
# 2020-08-07 05:12:00+00:00      8  United States of America               1
# 2020-08-06 04:01:00+00:00      8                     China               1
# 2020-08-04 23:57:00+00:00      8  United States of America               1
# 2020-07-30 21:25:00+00:00      7                Kazakhstan               1
# 2020-07-30 11:50:00+00:00      7  United States of America               1

# %%
table = pd.pivot_table(df, values='year', index='country',
                    columns='mission_status', aggfunc='count', fill_value=0)
table['Success (in prc)'] = table['Success'] / table.sum(axis=1)
table.style.format({'Success (in prc)' : '{:.2%}'})\
           .background_gradient(cmap='Reds')\
           .background_gradient(cmap='Greens',subset=["Success"])\
           .background_gradient(cmap='Greens',subset=["Success (in prc)"])
# Out:
# <style  type="text/css" >
#     #T_d3c31b96_ec6f_11ea_892d_acde48001122row0_col0 {
#             background-color:  #fff2eb;
#             color:  #000000;
#         }    #T_d3c31b96_ec6f_11ea_892d_acde48001122row0_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_d3c31b96_ec6f_11ea_892d_acde48001122row0_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_d3c31b96_ec6f_11ea_892d_acde48001122row0_col3 {
#             background-color:  #fff5f0;
#             color:  #000000;
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_d3c31b96_ec6f_11ea_892d_acde48001122row0_col4 {
#             background-color:  #fb694a;
#             color:  #000000;
#             background-color:  #73c476;
#             color:  #000000;
#         }    #T_d3c31b96_ec6f_11ea_892d_acde48001122row1_col0 {
#             background-color:  #fff3ed;
#             color:  #000000;
#         }    #T_d3c31b96_ec6f_11ea_892d_acde48001122row1_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_d3c31b96_ec6f_11ea_892d_acde48001122row1_col2 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_d3c31b96_ec6f_11ea_892d_acde48001122row1_col3 {
#             background-color:  #fff5f0;
#             color:  #000000;
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_d3c31b96_ec6f_11ea_892d_acde48001122row1_col4 {
#             background-color:  #fff5f0;
#             color:  #000000;
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_d3c31b96_ec6f_11ea_892d_acde48001122row2_col0 {
#             background-color:  #fedbcc;
#             color:  #000000;
#         }    #T_d3c31b96_ec6f_11ea_892d_acde48001122row2_col1 {
#             background-color:  #fdd0bc;
#             color:  #000000;
#         }    #T_d3c31b96_ec6f_11ea_892d_acde48001122row2_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_d3c31b96_ec6f_11ea_892d_acde48001122row2_col3 {
#             background-color:  #fdcebb;
#             color:  #000000;
#             background-color:  #d7efd1;
#             color:  #000000;
#         }    #T_d3c31b96_ec6f_11ea_892d_acde48001122row2_col4 {
#             background-color:  #940b13;
#             color:  #f1f1f1;
#             background-color:  #006227;
#             color:  #f1f1f1;
#         }    #T_d3c31b96_ec6f_11ea_892d_acde48001122row3_col0 {
#             background-color:  #fee5d8;
#             color:  #000000;
#         }    #T_d3c31b96_ec6f_11ea_892d_acde48001122row3_col1 {
#             background-color:  #fed9c9;
#             color:  #000000;
#         }    #T_d3c31b96_ec6f_11ea_892d_acde48001122row3_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_d3c31b96_ec6f_11ea_892d_acde48001122row3_col3 {
#             background-color:  #fdc5ae;
#             color:  #000000;
#             background-color:  #cfecc9;
#             color:  #000000;
#         }    #T_d3c31b96_ec6f_11ea_892d_acde48001122row3_col4 {
#             background-color:  #840711;
#             color:  #f1f1f1;
#             background-color:  #005723;
#             color:  #f1f1f1;
#         }    #T_d3c31b96_ec6f_11ea_892d_acde48001122row4_col0 {
#             background-color:  #ffebe2;
#             color:  #000000;
#         }    #T_d3c31b96_ec6f_11ea_892d_acde48001122row4_col1 {
#             background-color:  #fed9c9;
#             color:  #000000;
#         }    #T_d3c31b96_ec6f_11ea_892d_acde48001122row4_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_d3c31b96_ec6f_11ea_892d_acde48001122row4_col3 {
#             background-color:  #ffede5;
#             color:  #000000;
#             background-color:  #f0f9ed;
#             color:  #000000;
#         }    #T_d3c31b96_ec6f_11ea_892d_acde48001122row4_col4 {
#             background-color:  #b21218;
#             color:  #f1f1f1;
#             background-color:  #0c7735;
#             color:  #f1f1f1;
#         }    #T_d3c31b96_ec6f_11ea_892d_acde48001122row5_col0 {
#             background-color:  #ffebe2;
#             color:  #000000;
#         }    #T_d3c31b96_ec6f_11ea_892d_acde48001122row5_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_d3c31b96_ec6f_11ea_892d_acde48001122row5_col2 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_d3c31b96_ec6f_11ea_892d_acde48001122row5_col3 {
#             background-color:  #fff5f0;
#             color:  #000000;
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_d3c31b96_ec6f_11ea_892d_acde48001122row5_col4 {
#             background-color:  #fc9879;
#             color:  #000000;
#             background-color:  #a7dba0;
#             color:  #000000;
#         }    #T_d3c31b96_ec6f_11ea_892d_acde48001122row6_col0 {
#             background-color:  #fff3ed;
#             color:  #000000;
#         }    #T_d3c31b96_ec6f_11ea_892d_acde48001122row6_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_d3c31b96_ec6f_11ea_892d_acde48001122row6_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_d3c31b96_ec6f_11ea_892d_acde48001122row6_col3 {
#             background-color:  #fff4ef;
#             color:  #000000;
#             background-color:  #f6fcf4;
#             color:  #000000;
#         }    #T_d3c31b96_ec6f_11ea_892d_acde48001122row6_col4 {
#             background-color:  #b61319;
#             color:  #f1f1f1;
#             background-color:  #107a37;
#             color:  #f1f1f1;
#         }    #T_d3c31b96_ec6f_11ea_892d_acde48001122row7_col0 {
#             background-color:  #fee8de;
#             color:  #000000;
#         }    #T_d3c31b96_ec6f_11ea_892d_acde48001122row7_col1 {
#             background-color:  #fee6da;
#             color:  #000000;
#         }    #T_d3c31b96_ec6f_11ea_892d_acde48001122row7_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_d3c31b96_ec6f_11ea_892d_acde48001122row7_col3 {
#             background-color:  #fee7db;
#             color:  #000000;
#             background-color:  #ebf7e7;
#             color:  #000000;
#         }    #T_d3c31b96_ec6f_11ea_892d_acde48001122row7_col4 {
#             background-color:  #9a0c14;
#             color:  #f1f1f1;
#             background-color:  #006529;
#             color:  #f1f1f1;
#         }    #T_d3c31b96_ec6f_11ea_892d_acde48001122row8_col0 {
#             background-color:  #f7593f;
#             color:  #000000;
#         }    #T_d3c31b96_ec6f_11ea_892d_acde48001122row8_col1 {
#             background-color:  #f14130;
#             color:  #f1f1f1;
#         }    #T_d3c31b96_ec6f_11ea_892d_acde48001122row8_col2 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_d3c31b96_ec6f_11ea_892d_acde48001122row8_col3 {
#             background-color:  #fb7555;
#             color:  #000000;
#             background-color:  #80ca80;
#             color:  #000000;
#         }    #T_d3c31b96_ec6f_11ea_892d_acde48001122row8_col4 {
#             background-color:  #a60f15;
#             color:  #f1f1f1;
#             background-color:  #016e2d;
#             color:  #f1f1f1;
#         }    #T_d3c31b96_ec6f_11ea_892d_acde48001122row9_col0 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_d3c31b96_ec6f_11ea_892d_acde48001122row9_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_d3c31b96_ec6f_11ea_892d_acde48001122row9_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_d3c31b96_ec6f_11ea_892d_acde48001122row9_col3 {
#             background-color:  #fff4ef;
#             color:  #000000;
#             background-color:  #f6fcf4;
#             color:  #000000;
#         }    #T_d3c31b96_ec6f_11ea_892d_acde48001122row9_col4 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#             background

# %%
def success_percent_by_country(df):
    """
    Takes in the space df and returns a table with the following by Country:
    Failure
    Partial Failure
    Prelaunch Failure
    Success
    Succes in percent
    """
    table = pd.pivot_table(df, values='year', index='country',
                    columns='mission_status', aggfunc='count', fill_value=0)
    table['Success (in prc)'] = table['Success'] / table.sum(axis=1)
    return table.style.format({'Success (in prc)' : '{:.2%}'})\
               .background_gradient(cmap='Reds')\
               .background_gradient(cmap='Greens',subset=["Success"])\
               .background_gradient(cmap='Greens',subset=["Success (in prc)"])

# %%
success_percent_by_country(df)
# Out:
# <style  type="text/css" >
#     #T_d3ccb9ee_ec6f_11ea_892d_acde48001122row0_col0 {
#             background-color:  #fff2eb;
#             color:  #000000;
#         }    #T_d3ccb9ee_ec6f_11ea_892d_acde48001122row0_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_d3ccb9ee_ec6f_11ea_892d_acde48001122row0_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_d3ccb9ee_ec6f_11ea_892d_acde48001122row0_col3 {
#             background-color:  #fff5f0;
#             color:  #000000;
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_d3ccb9ee_ec6f_11ea_892d_acde48001122row0_col4 {
#             background-color:  #fb694a;
#             color:  #000000;
#             background-color:  #73c476;
#             color:  #000000;
#         }    #T_d3ccb9ee_ec6f_11ea_892d_acde48001122row1_col0 {
#             background-color:  #fff3ed;
#             color:  #000000;
#         }    #T_d3ccb9ee_ec6f_11ea_892d_acde48001122row1_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_d3ccb9ee_ec6f_11ea_892d_acde48001122row1_col2 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_d3ccb9ee_ec6f_11ea_892d_acde48001122row1_col3 {
#             background-color:  #fff5f0;
#             color:  #000000;
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_d3ccb9ee_ec6f_11ea_892d_acde48001122row1_col4 {
#             background-color:  #fff5f0;
#             color:  #000000;
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_d3ccb9ee_ec6f_11ea_892d_acde48001122row2_col0 {
#             background-color:  #fedbcc;
#             color:  #000000;
#         }    #T_d3ccb9ee_ec6f_11ea_892d_acde48001122row2_col1 {
#             background-color:  #fdd0bc;
#             color:  #000000;
#         }    #T_d3ccb9ee_ec6f_11ea_892d_acde48001122row2_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_d3ccb9ee_ec6f_11ea_892d_acde48001122row2_col3 {
#             background-color:  #fdcebb;
#             color:  #000000;
#             background-color:  #d7efd1;
#             color:  #000000;
#         }    #T_d3ccb9ee_ec6f_11ea_892d_acde48001122row2_col4 {
#             background-color:  #940b13;
#             color:  #f1f1f1;
#             background-color:  #006227;
#             color:  #f1f1f1;
#         }    #T_d3ccb9ee_ec6f_11ea_892d_acde48001122row3_col0 {
#             background-color:  #fee5d8;
#             color:  #000000;
#         }    #T_d3ccb9ee_ec6f_11ea_892d_acde48001122row3_col1 {
#             background-color:  #fed9c9;
#             color:  #000000;
#         }    #T_d3ccb9ee_ec6f_11ea_892d_acde48001122row3_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_d3ccb9ee_ec6f_11ea_892d_acde48001122row3_col3 {
#             background-color:  #fdc5ae;
#             color:  #000000;
#             background-color:  #cfecc9;
#             color:  #000000;
#         }    #T_d3ccb9ee_ec6f_11ea_892d_acde48001122row3_col4 {
#             background-color:  #840711;
#             color:  #f1f1f1;
#             background-color:  #005723;
#             color:  #f1f1f1;
#         }    #T_d3ccb9ee_ec6f_11ea_892d_acde48001122row4_col0 {
#             background-color:  #ffebe2;
#             color:  #000000;
#         }    #T_d3ccb9ee_ec6f_11ea_892d_acde48001122row4_col1 {
#             background-color:  #fed9c9;
#             color:  #000000;
#         }    #T_d3ccb9ee_ec6f_11ea_892d_acde48001122row4_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_d3ccb9ee_ec6f_11ea_892d_acde48001122row4_col3 {
#             background-color:  #ffede5;
#             color:  #000000;
#             background-color:  #f0f9ed;
#             color:  #000000;
#         }    #T_d3ccb9ee_ec6f_11ea_892d_acde48001122row4_col4 {
#             background-color:  #b21218;
#             color:  #f1f1f1;
#             background-color:  #0c7735;
#             color:  #f1f1f1;
#         }    #T_d3ccb9ee_ec6f_11ea_892d_acde48001122row5_col0 {
#             background-color:  #ffebe2;
#             color:  #000000;
#         }    #T_d3ccb9ee_ec6f_11ea_892d_acde48001122row5_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_d3ccb9ee_ec6f_11ea_892d_acde48001122row5_col2 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_d3ccb9ee_ec6f_11ea_892d_acde48001122row5_col3 {
#             background-color:  #fff5f0;
#             color:  #000000;
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_d3ccb9ee_ec6f_11ea_892d_acde48001122row5_col4 {
#             background-color:  #fc9879;
#             color:  #000000;
#             background-color:  #a7dba0;
#             color:  #000000;
#         }    #T_d3ccb9ee_ec6f_11ea_892d_acde48001122row6_col0 {
#             background-color:  #fff3ed;
#             color:  #000000;
#         }    #T_d3ccb9ee_ec6f_11ea_892d_acde48001122row6_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_d3ccb9ee_ec6f_11ea_892d_acde48001122row6_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_d3ccb9ee_ec6f_11ea_892d_acde48001122row6_col3 {
#             background-color:  #fff4ef;
#             color:  #000000;
#             background-color:  #f6fcf4;
#             color:  #000000;
#         }    #T_d3ccb9ee_ec6f_11ea_892d_acde48001122row6_col4 {
#             background-color:  #b61319;
#             color:  #f1f1f1;
#             background-color:  #107a37;
#             color:  #f1f1f1;
#         }    #T_d3ccb9ee_ec6f_11ea_892d_acde48001122row7_col0 {
#             background-color:  #fee8de;
#             color:  #000000;
#         }    #T_d3ccb9ee_ec6f_11ea_892d_acde48001122row7_col1 {
#             background-color:  #fee6da;
#             color:  #000000;
#         }    #T_d3ccb9ee_ec6f_11ea_892d_acde48001122row7_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_d3ccb9ee_ec6f_11ea_892d_acde48001122row7_col3 {
#             background-color:  #fee7db;
#             color:  #000000;
#             background-color:  #ebf7e7;
#             color:  #000000;
#         }    #T_d3ccb9ee_ec6f_11ea_892d_acde48001122row7_col4 {
#             background-color:  #9a0c14;
#             color:  #f1f1f1;
#             background-color:  #006529;
#             color:  #f1f1f1;
#         }    #T_d3ccb9ee_ec6f_11ea_892d_acde48001122row8_col0 {
#             background-color:  #f7593f;
#             color:  #000000;
#         }    #T_d3ccb9ee_ec6f_11ea_892d_acde48001122row8_col1 {
#             background-color:  #f14130;
#             color:  #f1f1f1;
#         }    #T_d3ccb9ee_ec6f_11ea_892d_acde48001122row8_col2 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_d3ccb9ee_ec6f_11ea_892d_acde48001122row8_col3 {
#             background-color:  #fb7555;
#             color:  #000000;
#             background-color:  #80ca80;
#             color:  #000000;
#         }    #T_d3ccb9ee_ec6f_11ea_892d_acde48001122row8_col4 {
#             background-color:  #a60f15;
#             color:  #f1f1f1;
#             background-color:  #016e2d;
#             color:  #f1f1f1;
#         }    #T_d3ccb9ee_ec6f_11ea_892d_acde48001122row9_col0 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_d3ccb9ee_ec6f_11ea_892d_acde48001122row9_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_d3ccb9ee_ec6f_11ea_892d_acde48001122row9_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_d3ccb9ee_ec6f_11ea_892d_acde48001122row9_col3 {
#             background-color:  #fff4ef;
#             color:  #000000;
#             background-color:  #f6fcf4;
#             color:  #000000;
#         }    #T_d3ccb9ee_ec6f_11ea_892d_acde48001122row9_col4 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#             background

# %%
data_fail = df[(df['mission_status'] != 'Success') & (df['mission_cost'] != 0)]

# %%
## Relationship between companies and mission status
active_df = df[df["rocket_status"] == "StatusActive"]
active_df = active_df.groupby("company_name").count()["rocket_type"].sort_values(ascending=False).reset_index()

# %%
active_df.head()
# Out:
# Empty DataFrame
# Columns: [company_name, rocket_type]
# Index: []

# %%
len(active_df)
# Out:
# 0

# %%
companies = df.groupby("company_name")["rocket_type"].count().sort_values(ascending=False).reset_index()
companies.head()
# Out:
#        company_name  rocket_type
# 0         RVSN USSR         1777
# 1       Arianespace          279
# 2  General Dynamics          251
# 3              CASC          251
# 4              NASA          203

# %%
len(companies)
# Out:
# 56

# %%
top = companies[1:40]
cmp = df.groupby(["company_name", "rocket_status"]).count()["rocket_type"].reset_index()
active = cmp[cmp["rocket_status"] == "active"].sort_values("rocket_type")
retired = cmp[cmp["rocket_status"] != "active"].sort_values("rocket_type")

# %%
cmp
# Out:
#     company_name rocket_status  rocket_type
# 0            AEB        active            3
# 1           AMBA       retired            8
# 2            ASI       retired            9
# 3    Arianespace        active          114
# 4    Arianespace       retired          165
# ..           ...           ...          ...
# 69        VKS RF        active           27
# 70        VKS RF       retired          174
# 71  Virgin Orbit        active            1
# 72      Yuzhmash       retired            2
# 73       i-Space        active            1
#
# [74 rows x 3 columns]

# %%
active
# Out:
#     company_name rocket_status  rocket_type
# 73       i-Space        active            1
# 59        Sandia        active            1
# 52      OneSpace        active            1
# 7         Boeing        active            1
# 38    Khrunichev        active            1
# 11         CASIC        active            1
# 17           ESA        active            1
# 71  Virgin Orbit        active            1
# 27          IRGC        active            1
# 0            AEB        active            3
# 36          KCST        active            3
# 21          Exos        active            4
# 23           IAI        active            5
# 33          JAXA        active            6
# 45          MITT        active            6
# 40   Land Launch        active            7
# 28           ISA        active            9
# 20        ExPace        active           10
# 6    Blue Origin        active           12
# 55    Rocket Lab        active           13
# 25           ILS        active           13
# 69        VKS RF        active           27
# 56     Roscosmos        active           32
# 43           MHI        active           32
# 60    Sea Launch        active           36
# 61        SpaceX        active           38
# 31          ISRO        active           50
# 49      Northrop        active           63
# 64           ULA        active           87
# 3    Arianespace        active          114
# 9           CASC        active          211

# %%
plt.figure(figsize=(16,16))

chart = sns.barplot(x=active.company_name, y=active.rocket_type, color="green")
chart.set_xticklabels(chart.get_xticklabels(), rotation=45)

plt.show()

# %%
plt.figure(figsize=(16,16))
chart1 = sns.barplot(x=retired.company_name, y=retired.rocket_type, color="red")
chart1.set_xticklabels(chart.get_xticklabels(), rotation=45)
plt.show()

# %%
cmp.head()
# Out:
#   company_name rocket_status  rocket_type
# 0          AEB        active            3
# 1         AMBA       retired            8
# 2          ASI       retired            9
# 3  Arianespace        active          114
# 4  Arianespace       retired          165

# %%
df.head()
# Out:
#                           company_name  \
# date_time
# 2020-08-07 05:12:00+00:00       SpaceX
# 2020-08-06 04:01:00+00:00         CASC
# 2020-08-04 23:57:00+00:00       SpaceX
# 2020-07-30 21:25:00+00:00    Roscosmos
# 2020-07-30 11:50:00+00:00          ULA
#
#                                                                     location  \
# date_time
# 2020-08-07 05:12:00+00:00         LC-39A, Kennedy Space Center, Florida, USA
# 2020-08-06 04:01:00+00:00  Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 2020-08-04 23:57:00+00:00                      Pad A, Boca Chica, Texas, USA
# 2020-07-30 21:25:00+00:00       Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 2020-07-30 11:50:00+00:00           SLC-41, Cape Canaveral AFS, Florida, USA
#
#                                                             rocket_type  \
# date_time
# 2020-08-07 05:12:00+00:00  Falcon 9 Block 5 | Starlink V1 L9 & BlackSky
# 2020-08-06 04:01:00+00:00           Long March 2D | Gaofen-9 04 & Q-SAT
# 2020-08-04 23:57:00+00:00            Starship Prototype | 150 Meter Hop
# 2020-07-30 21:25:00+00:00  Proton-M/Briz-M | Ekspress-80 & Ekspress-103
# 2020-07-30 11:50:00+00:00                    Atlas V 541 | Perseverance
#
#                           rocket_status mission_cost mission_status  year  \
# date_time
# 2020-08-07 05:12:00+00:00        active         50.0        Success  2020
# 2020-08-06 04:01:00+00:00        active        29.75        Success  2020
# 2020-08-04 23:57:00+00:00        active            0        Success  2020
# 2020-07-30 21:25:00+00:00        active         65.0        Success  2020
# 2020-07-30 11:50:00+00:00        active        145.0        Success  2020
#
#                            month                   country  mission_result
# date_time
# 2020-08-07 05:12:00+00:00      8  United States of America               1
# 2020-08-06 04:01:00+00:00      8                     China               1
# 2020-08-04 23:57:00+00:00      8  United States of America               1
# 2020-07-30 21:25:00+00:00      7                Kazakhstan               1
# 2020-07-30 11:50:00+00:00      7  United States of America               1

# %% [markdown]
# ## Launches by Company

# %%
#create a dataframe counting the number of times each company appears in a row
company_numbers = df["company_name"].value_counts().reset_index()
company_numbers
# Out:
#                index  company_name
# 0          RVSN USSR          1777
# 1        Arianespace           279
# 2   General Dynamics           251
# 3               CASC           251
# 4               NASA           203
# 5             VKS RF           201
# 6       US Air Force           161
# 7                ULA           140
# 8             Boeing           136
# 9    Martin Marietta           114
# 10            SpaceX           100
# 11               MHI            84
# 12          Northrop            83
# 13          Lockheed            79
# 14              ISRO            76
# 15         Roscosmos            55
# 16               ILS            46
# 17        Sea Launch            36
# 18              ISAS            30
# 19         Kosmotras            22
# 20           US Navy            17
# 21               ESA            13
# 22               ISA            13
# 23        Rocket Lab            13
# 24          Eurockot            13
# 25       Blue Origin            12
# 26               IAI            11
# 27            ExPace            10
# 28               ASI             9
# 29              CNES             8
# 30              AMBA             8
# 31              JAXA             7
# 32       Land Launch             7
# 33              MITT             7
# 34                UT             5
# 35              KCST             5
# 36             CASIC             5
# 37            CECLES             4
# 38   Arm??e de l'Air             4
# 39              Exos             4
# 40              KARI             3
# 41               SRC             3
# 42               AEB             3
# 43           OKB-586             2
# 44          Yuzhmash             2
# 45               RAE             2
# 46        Khrunichev             1
# 47         Landspace             1
# 48               EER             1
# 49              IRGC             1
# 50      Virgin Orbit             1
# 51            Sandia             1
# 52          OneSpace             1
# 53           Starsem             1
# 54           Douglas             1
# 55           i-Space             1

# %%
#rename the columns to mathc what they represent
company_numbers.columns = ["company_name", "number_of_launches"]

# %%
company_numbers
# Out:
#         company_name  number_of_launches
# 0          RVSN USSR                1777
# 1        Arianespace                 279
# 2   General Dynamics                 251
# 3               CASC                 251
# 4               NASA                 203
# 5             VKS RF                 201
# 6       US Air Force                 161
# 7                ULA                 140
# 8             Boeing                 136
# 9    Martin Marietta                 114
# 10            SpaceX                 100
# 11               MHI                  84
# 12          Northrop                  83
# 13          Lockheed                  79
# 14              ISRO                  76
# 15         Roscosmos                  55
# 16               ILS                  46
# 17        Sea Launch                  36
# 18              ISAS                  30
# 19         Kosmotras                  22
# 20           US Navy                  17
# 21               ESA                  13
# 22               ISA                  13
# 23        Rocket Lab                  13
# 24          Eurockot                  13
# 25       Blue Origin                  12
# 26               IAI                  11
# 27            ExPace                  10
# 28               ASI                   9
# 29              CNES                   8
# 30              AMBA                   8
# 31              JAXA                   7
# 32       Land Launch                   7
# 33              MITT                   7
# 34                UT                   5
# 35              KCST                   5
# 36             CASIC                   5
# 37            CECLES                   4
# 38   Arm??e de l'Air                   4
# 39              Exos                   4
# 40              KARI                   3
# 41               SRC                   3
# 42               AEB                   3
# 43           OKB-586                   2
# 44          Yuzhmash                   2
# 45               RAE                   2
# 46        Khrunichev                   1
# 47         Landspace                   1
# 48               EER                   1
# 49              IRGC                   1
# 50      Virgin Orbit                   1
# 51            Sandia                   1
# 52          OneSpace                   1
# 53           Starsem                   1
# 54           Douglas                   1
# 55           i-Space                   1

# %%
plt.figure(figsize=(16,24))
sns.barplot(x = company_numbers.number_of_launches, y = company_numbers.company_name, color = "#39FF14")
plt.title("Number of Launches per Company")
plt.show()

# %%
df.head(1)
# Out:
#                           company_name  \
# date_time
# 2020-08-07 05:12:00+00:00       SpaceX
#
#                                                              location  \
# date_time
# 2020-08-07 05:12:00+00:00  LC-39A, Kennedy Space Center, Florida, USA
#
#                                                             rocket_type  \
# date_time
# 2020-08-07 05:12:00+00:00  Falcon 9 Block 5 | Starlink V1 L9 & BlackSky
#
#                           rocket_status mission_cost mission_status  year  \
# date_time
# 2020-08-07 05:12:00+00:00        active         50.0        Success  2020
#
#                            month                   country  mission_result
# date_time
# 2020-08-07 05:12:00+00:00      8  United States of America               1

# %%
df.dtypes
# Out:
# company_name      object
# location          object
# rocket_type       object
# rocket_status     object
# mission_cost      object
# mission_status    object
# year               int64
# month              int64
# country           object
# mission_result     int64
# dtype: object

# %%
df.mission_cost = df.mission_cost.str.replace(' ', '')
df.mission_cost = df.mission_cost.str.replace(',', '')
df.mission_cost = df.mission_cost.astype(float)
df.mission_cost = df.mission_cost.fillna(0)

# %% [markdown]
# ## Rocket Value Distribution

# %%
not_zero = df[df.mission_cost != 0]
not_zero.mission_cost = not_zero.mission_cost * 1000000

# %%
not_zero
# Out:
#                            company_name  \
# date_time
# 2020-08-07 05:12:00+00:00        SpaceX
# 2020-08-06 04:01:00+00:00          CASC
# 2020-07-30 21:25:00+00:00     Roscosmos
# 2020-07-30 11:50:00+00:00           ULA
# 2020-07-25 03:13:00+00:00          CASC
# ...                                 ...
# 1966-07-29 18:43:00+00:00  US Air Force
# 1965-05-06 15:00:00+00:00  US Air Force
# 1965-02-11 15:19:00+00:00  US Air Force
# 1964-12-10 16:52:00+00:00  US Air Force
# 1964-09-01 15:00:00+00:00  US Air Force
#
#                                                                     location  \
# date_time
# 2020-08-07 05:12:00+00:00         LC-39A, Kennedy Space Center, Florida, USA
# 2020-08-06 04:01:00+00:00  Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 2020-07-30 21:25:00+00:00       Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 2020-07-30 11:50:00+00:00           SLC-41, Cape Canaveral AFS, Florida, USA
# 2020-07-25 03:13:00+00:00       LC-9, Taiyuan Satellite Launch Center, China
# ...                                                                      ...
# 1966-07-29 18:43:00+00:00            SLC-4W, Vandenberg AFB, California, USA
# 1965-05-06 15:00:00+00:00           SLC-20, Cape Canaveral AFS, Florida, USA
# 1965-02-11 15:19:00+00:00           SLC-20, Cape Canaveral AFS, Florida, USA
# 1964-12-10 16:52:00+00:00           SLC-20, Cape Canaveral AFS, Florida, USA
# 1964-09-01 15:00:00+00:00           SLC-20, Cape Canaveral AFS, Florida, USA
#
#                                                                  rocket_type  \
# date_time
# 2020-08-07 05:12:00+00:00       Falcon 9 Block 5 | Starlink V1 L9 & BlackSky
# 2020-08-06 04:01:00+00:00                Long March 2D | Gaofen-9 04 & Q-SAT
# 2020-07-30 21:25:00+00:00       Proton-M/Briz-M | Ekspress-80 & Ekspress-103
# 2020-07-30 11:50:00+00:00                         Atlas V 541 | Perseverance
# 2020-07-25 03:13:00+00:00  Long March 4B | Ziyuan-3 03, Apocalypse-10 & N...
# ...                                                                      ...
# 1966-07-29 18:43:00+00:00                                  Titan IIIB | KH-8
# 1965-05-06 15:00:00+00:00                         Titan IIIA | LES 2 & LCS 1
# 1965-02-11 15:19:00+00:00                                 Titan IIIA | LES 1
# 1964-12-10 16:52:00+00:00                           Titan IIIA | Transtage 2
# 1964-09-01 15:00:00+00:00                           Titan IIIA | Transtage 1
#
#                           rocket_status  mission_cost mission_status  year  \
# date_time
# 2020-08-07 05:12:00+00:00        active    50000000.0        Success  2020
# 2020-08-06 04:01:00+00:00        active    29750000.0        Success  2020
# 2020-07-30 21:25:00+00:00        active    65000000.0        Success  2020
# 2020-07-30 11:50:00+00:00        active   145000000.0        Success  2020
# 2020-07-25 03:13:00+00:00        active    64680000.0        Success  2020
# ...                                 ...           ...            ...   ...
# 1966-07-29 18:43:00+00:00       retired    59000000.0        Success  1966
# 1965-05-06 15:00:00+00:00       retired    63230000.0        Success  1965
# 1965-02-11 15:19:00+00:00       retired    63230000.0        Success  1965
# 1964-12-10 16:52:00+00:00       retired    63230000.0        Success  1964
# 1964-09-01 15:00:00+00:00       retired    63230000.0        Failure  1964
#
#                            month                   country  mission_result
# date_time
# 2020-08-07 05:12:00+00:00      8  United States of America               1
# 2020-08-06 04:01:00+00:00      8                     China               1
# 2020-07-30 21:25:00+00:00      7                Kazakhstan               1
# 2020-07-30 11:50:00+00:00      7  United States of America               1
# 2020-07-25 03:13:00+00:00      7                     China               1
# ...                          ...                       ...             ...
# 1966-07-29 18:43:00+00:00      7  United States of America               1
# 1965-05-06 15:00:00+00:00      5  United States of America               1
# 1965-02-11 15:19:00+00:00      2  United States of America               1
# 1964-12-10 16:52:00+00:00     12  United States of America               1
# 1964-09-01 15:00:00+00:00      9  United States of America               0
#
# [964 rows x 10 columns]

# %%
plt.figure(figsize = (16,16))
sns.distplot(not_zero.mission_cost, kde = False, bins = 100, color = "#39FF14")
plt.title("Distribution of Mission Cost - in Millions")
plt.show()

# %%
df.head(1)
# Out:
#                           company_name  \
# date_time
# 2020-08-07 05:12:00+00:00       SpaceX
#
#                                                              location  \
# date_time
# 2020-08-07 05:12:00+00:00  LC-39A, Kennedy Space Center, Florida, USA
#
#                                                             rocket_type  \
# date_time
# 2020-08-07 05:12:00+00:00  Falcon 9 Block 5 | Starlink V1 L9 & BlackSky
#
#                           rocket_status  mission_cost mission_status  year  \
# date_time
# 2020-08-07 05:12:00+00:00        active          50.0        Success  2020
#
#                            month                   country  mission_result
# date_time
# 2020-08-07 05:12:00+00:00      8  United States of America               1

# %% [markdown]
# ## Yearly Distribution

# %%
year_df = df["year"].value_counts().reset_index()
year_df.columns = ["year", "count"]

plt.figure(figsize=(16,16))
chart = sns.barplot(x=year_df["year"], y= year_df["count"], color = "#39FF14")
chart.set_xticklabels(chart.get_xticklabels(), rotation=90, fontsize= 12)
plt.title("Number of Missions by Year", fontsize = 14)
plt.show()

# %% [markdown]
# ## Monthly Distribution

# %%
monthly_df = df["month"].value_counts().reset_index()
monthly_df.columns = ["month", "count"]

plt.figure(figsize= (16,16))
chart = sns.barplot(x = monthly_df["month"], y = monthly_df["count"], color = "#39FF14")
chart.set_xticklabels(chart.get_xticklabels(), fontsize= 12)
plt.title("Number of Missions by Month", fontsize = 14)
plt.show()
